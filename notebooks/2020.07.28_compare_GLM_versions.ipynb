# %%
import visual_behavior_glm.src.GLM_visualization_tools as gvt
import visual_behavior_glm.src.GLM_analysis_tools as gat
# Out:
# /home/dougo/.conda/envs/visual_behavior/lib/python3.8/visual_behavior_glm/src/GLM_visualization_tools.py:435: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if axis_name is not 'kernel_contributions':
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_api/behavior_ophys_nwb_api.py:9: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# %matplotlib notebook

# %% [markdown]
# ## results from running the GLM are cached in a mongo database.

# %%
results = gat.retrieve_results()

# %% [markdown]
# ## Now plot variance explained for the versions that have been run as a batch

# %%
fig, ax = gvt.compare_var_explained(results['full'])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## get median variance explained for each version/cre-line

# %%
results_summary = results['full'].groupby(['glm_version','cre_line'])['Full_avg_cv_var_test'].describe()
results_summary
# Out:
#                                  count      mean       std         min  \
# glm_version cre_line
# 2           Slc17a7-IRES2-Cre    505.0  0.017257  0.079609   -1.028423
#             Vip-IRES-Cre          22.0  0.022184  0.030679   -0.041848
# 3           Slc17a7-IRES2-Cre  28527.0  0.034464  0.330567  -28.733207
#             Sst-IRES-Cre        1531.0  0.100415  0.844842  -28.769720
#             Vip-IRES-Cre        3975.0 -0.007902  1.940767 -119.551171
#
#                                     25%       50%       75%       max
# glm_version cre_line
# 2           Slc17a7-IRES2-Cre -0.001394  0.005579  0.025269  0.786520
#             Vip-IRES-Cre      -0.001107  0.015859  0.040425  0.090750
# 3           Slc17a7-IRES2-Cre  0.006412  0.023023  0.058675  0.744230
#             Sst-IRES-Cre       0.040007  0.115677  0.205284  0.846377
#             Vip-IRES-Cre       0.000478  0.015995  0.056696  0.439917
