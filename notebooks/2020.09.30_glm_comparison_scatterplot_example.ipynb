# %%
import visual_behavior_glm.GLM_visualization_tools as gvt
import visual_behavior_glm.GLM_analysis_tools as gat
import seaborn as sns
import numpy as np

# %%
# %%time
versions_to_compare = [
    '9a_L2_optimize_by_session',
    '10a_L2_optimize_by_session'
]
comparison_table = gat.get_glm_version_comparison_table(versions_to_compare)
# Out:
# CPU times: user 1min 30s, sys: 14.9 s, total: 1min 45s
# Wall time: 2min 26s

# %%
jointplot = gvt.plot_glm_version_comparison(comparison_table, versions_to_compare=versions_to_compare)
