# %%
from visual_behavior_glm.glm import GLM
import visual_behavior_glm.GLM_fit_tools as gft
import visual_behavior_glm.GLM_analysis_tools as gat
import visual_behavior_glm.GLM_visualization_tools as gvt

import visual_behavior.utilities as vbu
import visual_behavior.plotting as vbp
import visual_behavior.data_access.loading as loading
import visual_behavior.visualization.utils as vis_utils
import visual_behavior.database as db

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
# %widescreen
# Out:
# <style>.container { width:100% !important; }</style>
# applied a custom magic command to make full use of screen width
# will only work if command is defined locally
# replace with the following to replicate functionality:
# 	from IPython.core.display import display, HTML
# 	display(HTML("<style>.container { width:100% !important; }</style>")

# %%
from allensdk.brain_observatory.behavior.behavior_ophys_session import BehaviorOphysSession
session = BehaviorOphysSession.from_lims(1007107386)

# %%
session.cell_specimen_table.loc[1007949380]
# Out:
# cell_roi_id                                                    1007173765
# height                                                                 26
# image_mask              [[False, False, False, False, False, False, Fa...
# mask_image_plane                                                        0
# max_correction_down                                               6.61338
# max_correction_left                                               5.93416
# max_correction_right                                              16.5545
# max_correction_up                                                 5.72533
# valid_roi                                                            True
# width                                                                  13
# x                                                                      70
# y                                                                      70
# Name: 1007949380, dtype: object

# %%
# oeid = 994279627
oeid = 1000744365
version = '9a_L2_optimize_by_session'
glm = GLM(oeid, version, use_previous_fit=True, log_results=False, log_weights=False)
# Out:
# importing GLM_fit_tools from /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_9a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py
# loading previous fit...
# extracting cached data from 1000744365_485152_200115_VISp_0_Slc17a7-IRES2-Cre_MESO.1_behavior_365
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# failed to load previous fit, reload flag is set to True
# Fitting ophys_experiment_id: 1000744365
# Loading data
# extracting cached data from 1000744365_485152_200115_VISp_0_Slc17a7-IRES2-Cre_MESO.1_behavior_365
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam2_exposure', 'cam1_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Code/visual_behavior_glm/visual_behavior_glm/glm.py in __init__(self, ophys_experiment_id, version, log_results, log_weights, use_previous_fit, recompute, use_inputs, inputs)
#      53                 print('loading previous fit...')
# ---> 54                 self.load_fit_model()
#      55                 print('done loading previous fit')
#
# ~/Code/visual_behavior_glm/visual_behavior_glm/glm.py in load_fit_model(self)
#     107         self.session, self.fit, self.design = self.gft.load_fit_experiment(
# --> 108             self.oeid, self.run_params)
#     109
#
# /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_9a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py in load_fit_experiment(ophys_experiment_id, run_params)
#      32     fit = gat.load_fit_pkl(run_params, ophys_experiment_id)
# ---> 33     session = load_data(ophys_experiment_id)
#      34     design = DesignMatrix(fit)
#
# /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_9a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py in load_data(oeid, dataframe_format, smooth_running_data)
#     712         use_extended_stimulus_presentations=True,
# --> 713         dataframe_format = dataframe_format
#     714     )
#
# ~/Code/visual_behavior_analysis/visual_behavior/ophys/response_analysis/response_analysis.py in __init__(self, dataset, analysis_cache_dir, load_from_cache, use_events, use_extended_stimulus_presentations, overwrite_analysis_files, dataframe_format)
#      87         # promote cell_specimen_table to the top level
# ---> 88         self.cell_specimen_table = self.dataset.cell_specimen_table
#      89         self.use_events = use_events
#
# ~/Code/visual_behavior_analysis/visual_behavior/data_access/loading.py in cell_specimen_table(self)
#     305         # add cell index corresponding to the index of the cell in dff_traces_array
# --> 306         cell_specimen_ids = np.sort(cell_specimen_table.index.values)
#     307         if 'cell_index' not in cell_specimen_table.columns:
#
# ~/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     933         a = asanyarray(a).copy(order="K")
# --> 934     a.sort(axis=axis, kind=kind, order=order)
#     935     return a
#
# TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bd38b40f2ba4> in <module>
#       2 oeid = 1000744365
#       3 version = '9a_L2_optimize_by_session'
# ----> 4 glm = GLM(oeid, version, use_previous_fit=True, log_results=False, log_weights=False)
#
# ~/Code/visual_behavior_glm/visual_behavior_glm/glm.py in __init__(self, ophys_experiment_id, version, log_results, log_weights, use_previous_fit, recompute, use_inputs, inputs)
#      58                 if recompute:
#      59                     # Just computes the model, since it crashed on load
# ---> 60                     self.fit_model()
#      61                 else:
#      62                     raise Exception('Crash during load_fit_model(), check if file exists')
#
# ~/Code/visual_behavior_glm/visual_behavior_glm/glm.py in fit_model(self)
#      99         '''
#     100         self.session, self.fit, self.design = self.gft.fit_experiment(
# --> 101             self.oeid, self.run_params)
#     102
#     103     def load_fit_model(self):
#
# /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_9a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py in fit_experiment(oeid, run_params, NO_DROPOUTS, TESTING)
#      84     # Load Data
#      85     print('Loading data')
# ---> 86     session = load_data(oeid)
#      87
#      88     # Processing df/f data
#
# /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_9a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py in load_data(oeid, dataframe_format, smooth_running_data)
#     711         overwrite_analysis_files=False,
#     712         use_extended_stimulus_presentations=True,
# --> 713         dataframe_format = dataframe_format
#     714     )
#     715     if smooth_running_data:
#
# ~/Code/visual_behavior_analysis/visual_behavior/ophys/response_analysis/response_analysis.py in __init__(self, dataset, analysis_cache_dir, load_from_cache, use_events, use_extended_stimulus_presentations, overwrite_analysis_files, dataframe_format)
#      86         self.dff_traces = self.dataset.dff_traces
#      87         # promote cell_specimen_table to the top level
# ---> 88         self.cell_specimen_table = self.dataset.cell_specimen_table
#      89         self.use_events = use_events
#      90         if analysis_cache_dir is None:
#
# ~/Code/visual_behavior_analysis/visual_behavior/data_access/loading.py in cell_specimen_table(self)
#     304         cell_specimen_table = cell_specimen_table.copy()
#     305         # add cell index corresponding to the index of the cell in dff_traces_array
# --> 306         cell_specimen_ids = np.sort(cell_specimen_table.index.values)
#     307         if 'cell_index' not in cell_specimen_table.columns:
#     308             cell_specimen_table['cell_index'] = [np.where(cell_specimen_ids == cell_specimen_id)[0][0] for
#
# ~/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     932     else:
#     933         a = asanyarray(a).copy(order="K")
# --> 934     a.sort(axis=axis, kind=kind, order=order)
#     935     return a
#     936
#
# TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'

# %%
glm.results.sort_values(by='Full__avg_cv_var_test',ascending=False)
# Out:
#                   Full__avg_cv_var_train  Full__avg_cv_var_test  \
# cell_specimen_id
# 1044470315                      0.286797               0.245392
# 1044470480                      0.248575               0.224929
# 1044470381                      0.222122               0.190624
# 1044470377                      0.209256               0.189255
# 1044470350                      0.128212               0.119450
# 1044470385                      0.122134               0.107180
# 1044470324                      0.111015               0.095913
# 1044470563                      0.099557               0.086569
# 1044470389                      0.081108               0.063786
# 1044470538                      0.070066               0.057496
# 1044470368                      0.065762               0.053116
# 1044470441                      0.065004               0.046051
# 1044470427                      0.027698               0.015634
# 1044470392                      0.026990               0.014555
# 1044470453                      0.020766               0.008971
#
#                   Full__avg_cv_var_test_full_comparison  \
# cell_specimen_id
# 1044470315                                     0.245392
# 1044470480                                     0.224929
# 1044470381                                     0.190624
# 1044470377                                     0.189255
# 1044470350                                     0.119450
# 1044470385                                     0.107180
# 1044470324                                     0.095913
# 1044470563                                     0.086569
# 1044470389                                     0.063786
# 1044470538                                     0.057496
# 1044470368                                     0.053116
# 1044470441                                     0.046051
# 1044470427                                     0.015634
# 1044470392                                     0.014555
# 1044470453                                     0.008971
#
#                   Full__avg_cv_adjvar_train  Full__avg_cv_adjvar_test  \
# cell_specimen_id
# 1044470315                         0.286797                  0.245392
# 1044470480                         0.248575                  0.224929
# 1044470381                         0.222122                  0.190624
# 1044470377                         0.209256                  0.189255
# 1044470350                         0.128212                  0.119450
# 1044470385                         0.122134                  0.107180
# 1044470324                         0.111015                  0.095913
# 1044470563                         0.099557                  0.086569
# 1044470389                         0.081108                  0.063786
# 1044470538                         0.070066                  0.057496
# 1044470368                         0.065762                  0.053116
# 1044470441                         0.065004                  0.046051
# 1044470427                         0.027698                  0.015634
# 1044470392                         0.026990                  0.014555
# 1044470453                         0.020766                  0.008971
#
#                   Full__avg_cv_adjvar_test_full_comparison  \
# cell_specimen_id
# 1044470315                                        0.245392
# 1044470480                                        0.224929
# 1044470381                                        0.190624
# 1044470377                                        0.189255
# 1044470350                                        0.119450
# 1044470385                                        0.107180
# 1044470324                                        0.095913
# 1044470563                                        0.086569
# 1044470389                                        0.063786
# 1044470538                                        0.057496
# 1044470368                                        0.053116
# 1044470441                                        0.046051
# 1044470427                                        0.015634
# 1044470392                                        0.014555
# 1044470453                                        0.008971
#
#                   Full__absolute_change_from_full  Full__adj_dropout  \
# cell_specimen_id
# 1044470315                                    0.0               -0.0
# 1044470480                                    0.0               -0.0
# 1044470381                                    0.0               -0.0
# 1044470377                                    0.0               -0.0
# 1044470350                                    0.0               -0.0
# 1044470385                                    0.0               -0.0
# 1044470324                                    0.0               -0.0
# 1044470563                                    0.0               -0.0
# 1044470389                                    0.0               -0.0
# 1044470538                                    0.0               -0.0
# 1044470368                                    0.0               -0.0
# 1044470441                                    0.0               -0.0
# 1044470427                                    0.0               -0.0
# 1044470392                                    0.0               -0.0
# 1044470453                                    0.0               -0.0
#
#                   Full__dropout  intercept__avg_cv_var_train  ...  \
# cell_specimen_id                                              ...
# 1044470315                 -0.0                     0.286604  ...
# 1044470480                 -0.0                     0.247542  ...
# 1044470381                 -0.0                     0.221693  ...
# 1044470377                 -0.0                     0.209186  ...
# 1044470350                 -0.0                     0.128198  ...
# 1044470385                 -0.0                     0.122128  ...
# 1044470324                 -0.0                     0.110984  ...
# 1044470563                 -0.0                     0.099552  ...
# 1044470389                 -0.0                     0.081037  ...
# 1044470538                 -0.0                     0.070060  ...
# 1044470368                 -0.0                     0.065755  ...
# 1044470441                 -0.0                     0.063474  ...
# 1044470427                 -0.0                     0.027695  ...
# 1044470392                 -0.0                     0.026990  ...
# 1044470453                 -0.0                     0.020764  ...
#
#                   single-cognitive__adj_dropout  \
# cell_specimen_id
# 1044470315                            -0.246477
# 1044470480                            -0.360352
# 1044470381                            -0.416143
# 1044470377                            -0.359586
# 1044470350                            -0.237231
# 1044470385                            -0.317825
# 1044470324                            -0.481129
# 1044470563                            -0.318407
# 1044470389                            -0.365829
# 1044470538                            -0.267504
# 1044470368                            -0.217393
# 1044470441                            -0.586535
# 1044470427                             0.000000
# 1044470392                             0.000000
# 1044470453                             0.000000
#
#                   single-task__avg_cv_var_train  single-task__avg_cv_var_test  \
# cell_specimen_id
# 1044470315                             0.019058                      0.016236
# 1044470480                             0.020325                      0.017228
# 1044470381                             0.024147                      0.020537
# 1044470377                             0.017487                      0.015073
# 1044470350                             0.006335                      0.004365
# 1044470385                             0.010190                      0.007118
# 1044470324                             0.014198                      0.010887
# 1044470563                             0.007285                      0.004267
# 1044470389                             0.005224                      0.003225
# 1044470538                             0.006509                      0.003219
# 1044470368                             0.005081                      0.001716
# 1044470441                             0.006815                      0.004015
# 1044470427                             0.004213                      0.000942
# 1044470392                             0.004090                      0.000701
# 1044470453                             0.003343                      0.000202
#
#                   single-task__avg_cv_var_test_full_comparison  \
# cell_specimen_id
# 1044470315                                            0.245392
# 1044470480                                            0.224929
# 1044470381                                            0.190624
# 1044470377                                            0.189255
# 1044470350                                            0.119450
# 1044470385                                            0.107180
# 1044470324                                            0.095913
# 1044470563                                            0.086569
# 1044470389                                            0.063786
# 1044470538                                            0.057496
# 1044470368                                            0.053116
# 1044470441                                            0.046051
# 1044470427                                            0.015634
# 1044470392                                            0.014555
# 1044470453                                            0.008971
#
#                   single-task__avg_cv_adjvar_train  \
# cell_specimen_id
# 1044470315                                0.068452
# 1044470480                                0.075121
# 1044470381                                0.083402
# 1044470377                                0.071980
# 1044470350                                0.036907
# 1044470385                                0.042305
# 1044470324                                0.055026
# 1044470563                                0.031436
# 1044470389                                0.027463
# 1044470538                                0.025644
# 1044470368                                0.020365
# 1044470441                                0.030414
# 1044470427                                0.016968
# 1044470392                                0.016244
# 1044470453                                0.013570
#
#                   single-task__avg_cv_adjvar_test  \
# cell_specimen_id
# 1044470315                               0.056683
# 1044470480                               0.071020
# 1044470381                               0.075612
# 1044470377                               0.061113
# 1044470350                               0.024012
# 1044470385                               0.029960
# 1044470324                               0.042659
# 1044470563                               0.018581
# 1044470389                               0.016230
# 1044470538                               0.012646
# 1044470368                               0.006902
# 1044470441                               0.018024
# 1044470427                               0.003756
# 1044470392                               0.002957
# 1044470453                               0.000814
#
#                   single-task__avg_cv_adjvar_test_full_comparison  \
# cell_specimen_id
# 1044470315                                               0.229972
# 1044470480                                               0.197085
# 1044470381                                               0.181697
# 1044470377                                               0.169955
# 1044470350                                               0.101216
# 1044470385                                               0.094266
# 1044470324                                               0.088665
# 1044470563                                               0.058357
# 1044470389                                               0.044364
# 1044470538                                               0.047273
# 1044470368                                               0.031751
# 1044470441                                               0.030729
# 1044470427                                               0.009312
# 1044470392                                               0.008182
# 1044470453                                               0.004424
#
#                   single-task__absolute_change_from_full  \
# cell_specimen_id
# 1044470315                                     -0.229156
# 1044470480                                     -0.207702
# 1044470381                                     -0.170087
# 1044470377                                     -0.174182
# 1044470350                                     -0.115085
# 1044470385                                     -0.100062
# 1044470324                                     -0.085026
# 1044470563                                     -0.082302
# 1044470389                                     -0.060561
# 1044470538                                     -0.054277
# 1044470368                                     -0.051400
# 1044470441                                     -0.042037
# 1044470427                                     -0.014691
# 1044470392                                     -0.013855
# 1044470453                                     -0.008770
#
#                   single-task__dropout  single-task__adj_dropout
# cell_specimen_id
# 1044470315                   -0.066163                 -0.246477
# 1044470480                   -0.076591                 -0.360352
# 1044470381                   -0.107737                 -0.416143
# 1044470377                   -0.079642                 -0.359586
# 1044470350                    0.000000                 -0.237231
# 1044470385                   -0.066411                 -0.317825
# 1044470324                   -0.113513                 -0.481129
# 1044470563                    0.000000                 -0.318407
# 1044470389                    0.000000                 -0.365829
# 1044470538                    0.000000                 -0.267504
# 1044470368                    0.000000                 -0.217393
# 1044470441                    0.000000                 -0.586535
# 1044470427                    0.000000                  0.000000
# 1044470392                    0.000000                  0.000000
# 1044470453                    0.000000                  0.000000
#
# [15 rows x 522 columns]

# %%
csid = 1044470368

# %%
self = gvt.GLM_Movie(glm, cell_specimen_id=csid, start_frame=20000, end_frame=20500, frame_interval=1, destination_folder='/home/dougo/OneDrive/glm_movies',fps=10)
# Out:
# here
# /home/dougo/Code/visual_behavior_analysis/visual_behavior/utilities.py:310: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   timestamp_file = h5py.File(filepath.replace('.avi', '.h5'))
# /home/dougo/Code/visual_behavior_analysis/visual_behavior/utilities.py:310: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   timestamp_file = h5py.File(filepath.replace('.avi', '.h5'))

# %%
# %%time
self.make_cell_movie_frame(self.ax, self.glm, F_index=20000, cell_specimen_id=self.cell_specimen_id, verbose=True)
# Out:
# setup done at 2.7839417457580566 seconds
# axis clearing done at 3.0235135555267334 seconds
# cell plotting done at 5.867652177810669 seconds
# behavior movie plotting done at 6.138989448547363 seconds
# FOV plot done at 6.148385047912598 seconds
# dff plots done at 6.170289516448975 seconds
# kernel plot done at 6.4837353229522705 seconds
# axis formatting done at 6.763493299484253 seconds
# CPU times: user 9.01 s, sys: 1.42 s, total: 10.4 s
# Wall time: 6.76 s

# %%
# %debug
# Out:
# > /home/dougo/Code/visual_behavior_glm/visual_behavior_glm/GLM_visualization_tools.py(935)make_cell_movie_frame()
#     933             this_cell.query(qs)['dff'].max(),
#     934         )
# --> 935         assert False
#     936
#     937         ax['cell_response'].legend(
#
# ipdb> this_cell.query(qs)['dff']
# 4340179   -0.218344
# Name: dff, dtype: float64
# ipdb> self.initial_time
# 954.23703
# ipdb> self.final_time
# 954.23703
# ipdb> q

# %%
self.make_movie()
# Out:
# 501it [15:56,  1.91s/it]

# %%
np.percentile(glm.session.dataset.eye_tracking['pupil_area'].fillna(0), 95)
# Out:
# 13933.915884948556

# %%
self.palette_df
# Out:
#           kernel_name                                       kernel_color
# 0           intercept  (0.009968179232284546, 0.4318454396151756, 0.6...
# 1                time  (0.48426790118158475, 0.33309050158442255, 0.9...
# 2           pre_licks  (0.4137999807436036, 0.9688847700993637, 0.224...
# 3          post_licks  (0.1397517039596199, 0.4541944469516509, 0.476...
# 4      pre_lick_bouts  (0.81719332260592, 0.10155867016996978, 0.5612...
# 5     post_lick_bouts  (0.481920893916228, 0.11580034545260803, 0.343...
# 6             rewards  (0.5612501698841906, 0.4440873501747524, 0.085...
# 7              change  (0.33029314839843393, 0.4083132647503653, 0.08...
# 8                hits  (0.6789280088196009, 0.22660815960415992, 0.02...
# 9              misses  (0.15134137035566975, 0.6935368245589338, 0.50...
# 10    correct_rejects  (0.4368155922682187, 0.1349005125505388, 0.068...
# 11          omissions  (0.08504345984556477, 0.34090791921992153, 0.2...
# 12  image_expectation  (0.1746674607160097, 0.21841481459414322, 0.59...
# 13            running  (0.2807634335013688, 0.6152312483394298, 0.116...
# 14              pupil  (0.11111150897863149, 0.061949374049525385, 0....
# 15   face_motion_PC_0  (0.07461241371998617, 0.4434636590760575, 0.88...
# 16   face_motion_PC_1  (0.5602710353088911, 0.12401350527899319, 0.05...
# 17   face_motion_PC_2  (0.061286300460343224, 0.35319592720639365, 0....
# 18   face_motion_PC_3  (0.2567951099949831, 0.480931804809178, 0.0774...
# 19   face_motion_PC_4  (0.050680506070947096, 0.21700131784198612, 0....
# 20             image0  (0.5438789129756644, 0.8593436498367062, 0.409...
# 21             image1  (0.20984988552665051, 0.08394018991704799, 0.8...
# 22             image2  (0.13074664183029527, 0.8655864115509352, 0.60...
# 23             image3  (0.6565845982915132, 0.6297254003369486, 0.199...
# 24             image4  (0.05603530197930082, 0.17884441636850917, 0.2...
# 25             image5  (0.22024595425873794, 0.08257602191569474, 0.2...
# 26             image6  (0.08122851639493285, 0.3040035643332314, 0.03...
# 27             image7  (0.2700706796429993, 0.4017274429879311, 0.004...

# %%
spreadsheet_path = "/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/2020.11.16.example_cells_shortlist.csv"
cell_list =pd.read_csv(spreadsheet_path)

# %%
cell_list
# Out:
#     Unnamed: 0             identifier  ophys_experiment_id  ophys_session_id  \
# 0            0  1007929142_1007949410           1007929142        1007733253
# 1            1  1044678595_1044470368           1044678595        1044580813
# 2            2  1044678595_1044470389           1044678595        1044580813
# 3            3  1000744365_1017235744           1000744365        1000439105
# 4            4  1000744370_1018149270           1000744370        1000439105
# 5            5  1000744370_1018149293           1000744370        1000439105
# 6            6  1044101384_1044470284           1044101384        1043965594
# 7            7  1044101384_1044470316           1044101384        1043965594
# 8            8  1044688146_1044470254           1044688146        1044587321
# 9            9   850517358_1028814694            850517358         849304162
# 10          10   851093291_1028819943            851093291         850667270
# 11          11   851093291_1028820148            851093291         850667270
# 12          12  1000744370_1018150256           1000744370        1000439105
# 13          13    775614751_962636982            775614751         775289198
# 14          14    778644591_962636722            778644591         778015591
# 15          15  1043833869_1044470254           1043833869        1043777491
# 16          16  1043833869_1044470262           1043833869        1043777491
# 17          17  1043833869_1044470301           1043833869        1043777491
# 18          18  1007107386_1007949380           1007107386        1006901110
# 19          19  1007107386_1007949384           1007107386        1006901110
# 20          20  1007107386_1007949391           1007107386        1006901110
# 21          21  1000744365_1017234763           1000744365        1000439105
# 22          22  1000744365_1017235405           1000744365        1000439105
# 23          23  1000744365_1017235793           1000744365        1000439105
# 24          24  1044688146_1044470305           1044688146        1044587321
# 25          25  1048483604_1050489976           1048483604        1048363441
# 26          26  1048483604_1050489982           1048483604        1048363441
#
#     cell_specimen_id           cre_line          category
# 0         1007949410       Sst-IRES-Cre   mid_vis_mid_beh
# 1         1044470368       Sst-IRES-Cre   mid_vis_mid_beh
# 2         1044470389       Sst-IRES-Cre   mid_vis_mid_beh
# 3         1017235744  Slc17a7-IRES2-Cre   mid_vis_mid_beh
# 4         1018149270  Slc17a7-IRES2-Cre   mid_vis_mid_beh
# 5         1018149293  Slc17a7-IRES2-Cre   mid_vis_mid_beh
# 6         1044470284       Vip-IRES-Cre   mid_vis_mid_beh
# 7         1044470316       Vip-IRES-Cre   mid_vis_mid_beh
# 8         1044470254       Vip-IRES-Cre   mid_vis_mid_beh
# 9         1028814694       Sst-IRES-Cre  low_vis_high_beh
# 10        1028819943       Sst-IRES-Cre  low_vis_high_beh
# 11        1028820148       Sst-IRES-Cre  low_vis_high_beh
# 12        1018150256  Slc17a7-IRES2-Cre  low_vis_high_beh
# 13         962636982  Slc17a7-IRES2-Cre  low_vis_high_beh
# 14         962636722  Slc17a7-IRES2-Cre  low_vis_high_beh
# 15        1044470254       Vip-IRES-Cre  low_vis_high_beh
# 16        1044470262       Vip-IRES-Cre  low_vis_high_beh
# 17        1044470301       Vip-IRES-Cre  low_vis_high_beh
# 18        1007949380       Sst-IRES-Cre  high_vis_low_beh
# 19        1007949384       Sst-IRES-Cre  high_vis_low_beh
# 20        1007949391       Sst-IRES-Cre  high_vis_low_beh
# 21        1017234763  Slc17a7-IRES2-Cre  high_vis_low_beh
# 22        1017235405  Slc17a7-IRES2-Cre  high_vis_low_beh
# 23        1017235793  Slc17a7-IRES2-Cre  high_vis_low_beh
# 24        1044470305       Vip-IRES-Cre  high_vis_low_beh
# 25        1050489976       Vip-IRES-Cre  high_vis_low_beh
# 26        1050489982       Vip-IRES-Cre  high_vis_low_beh

# %%
# %%time
def get_max_locs_df(df_in):
    df_in = df_in.copy()
    df_in['kernel_outputs_abs'] = df_in['kernel_outputs'].abs()
    max_df = df_in.groupby('kernel_name')[['kernel_outputs','kernel_outputs_abs']].max().sort_values(by='kernel_outputs', ascending=False)
    max_locs = []
    for kernel_name,row in max_df.iterrows():
        kernel_subset = df_in.query('kernel_name == @kernel_name')
        m = subset['kernel_outputs_abs'].abs().max()
        max_locs.append({
            'kernel_name': kernel_name,
            'abs_max_value': kernel_subset['kernel_outputs_abs'].abs().max(),
            'abs_max_sign': np.sign(kernel_subset.loc[kernel_subset['kernel_outputs_abs'].idxmax()]['kernel_outputs']),
            'idx': kernel_subset['kernel_outputs_abs'].idxmax(),
            'time': kernel_subset.loc[kernel_subset['kernel_outputs_abs'].idxmax()]['timestamps'],
            'percentile':stats.percentileofscore(df_in['kernel_outputs_abs'], kernel_subset['kernel_outputs_abs'].abs().max(), kind='strict')
        })
    return pd.DataFrame(max_locs)
# Out:
# CPU times: user 17 µs, sys: 0 ns, total: 17 µs
# Wall time: 26 µs

# %%
kernel_df = self.kernel_df
t0,t1 = t_span
kernels_to_exclude_from_plot = ['intercept','time','model_task0','model_timing1D','model_bias','model_omissions1']
data_to_plot = kernel_df.query('timestamps >= @t0 and timestamps <= @t1 and kernel_name not in @kernels_to_exclude_from_plot')

# %%
# %%time
max_locs = get_max_locs_df(data_to_plot)
max_locs
# Out:
# CPU times: user 94.9 ms, sys: 193 µs, total: 95.1 ms
# Wall time: 76.3 ms
#           kernel_name  abs_max_value  abs_max_sign    idx        time  \
# 0          post_licks       0.565341           1.0  14923  1708.65092
# 1               pupil       0.218670           1.0  14891  1705.66747
# 2             rewards       0.091857           1.0  14927  1709.02385
# 3    face_motion_PC_4       0.081995           1.0  14940  1710.23588
# 4    face_motion_PC_1       0.070491           1.0  14936  1709.86294
# 5                hits       0.069007           1.0  14924  1708.74415
# 6              change       0.068273           1.0  14927  1709.02385
# 7    face_motion_PC_3       0.060815           1.0  14923  1708.65092
# 8    face_motion_PC_2       0.052254          -1.0  14886  1705.20131
# 9    face_motion_PC_0       0.099046          -1.0  14945  1710.70204
# 10    post_lick_bouts       0.066959          -1.0  14863  1703.05696
# 11          pre_licks       0.172126          -1.0  14904  1706.87950
# 12     pre_lick_bouts       0.022001           1.0  14847  1701.56524
# 13  image_expectation       0.013926           1.0  14834  1700.35322
# 14             image0       0.012095           1.0  14908  1707.25243
# 15             image6       0.015724          -1.0  14834  1700.35322
# 16            running       0.218408          -1.0  14983  1714.24488
# 17             misses       0.000000           0.0  14831  1700.07352
# 18          omissions       0.000000           0.0  14831  1700.07352
# 19             image7       0.000000           0.0  14831  1700.07352
# 20    correct_rejects       0.000000           0.0  14831  1700.07352
# 21             image4       0.000000           0.0  14831  1700.07352
# 22             image3       0.000000           0.0  14831  1700.07352
# 23             image2       0.000000           0.0  14831  1700.07352
# 24             image1       0.000000           0.0  14831  1700.07352
# 25             image5       0.000000           0.0  14831  1700.07352
#
#     percentile
# 0    99.982027
# 1    98.382459
# 2    89.863408
# 3    89.521927
# 4    88.964774
# 5    88.892883
# 6    88.820992
# 7    88.407620
# 8    87.778577
# 9    90.061107
# 10   88.677211
# 11   95.039540
# 12   81.991373
# 13   75.754853
# 14   73.759885
# 15   77.767793
# 16   98.364486
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000000
# 25    0.000000

# %%
fig,ax=plt.subplots(figsize=(20,10))
t_span=(1700,1720)
gvt.plot_kernels(self.kernel_df, ax, self.palette_df, t_span, legend=False)
gvt.plot_stimuli(glm.session, ax, t_span=t_span)

# percentile_threshold = 90
# for idx,row in max_locs.iterrows():
#     kernel_name = row['kernel_name']
#     if row['percentile'] > percentile_threshold:
#         va = 'top' if row['abs_max_sign'] < 0 else 'bottom'
#         ax.text(
#             row['time'], 
#             row['abs_max_sign']*row['abs_max_value'],
#             row['kernel_name'],
#             ha='center',
#             va=va,
#             fontweight='bold',
#             color=self.palette_df.query('kernel_name == @kernel_name')['kernel_color'].iloc[0],
#             fontsize=15
#         )

# %%
ax.set_yl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-68525aee600c> in <module>
# ----> 1 ax.set_yl
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_yl'

# %%
self.kernel_df['kernel_name'].unique()
# Out:
# array(['intercept', 'time', 'pre_licks', 'post_licks', 'pre_lick_bouts',
#        'post_lick_bouts', 'rewards', 'change', 'hits', 'misses',
#        'correct_rejects', 'omissions', 'image_expectation', 'running',
#        'pupil', 'face_motion_PC_0', 'face_motion_PC_1',
#        'face_motion_PC_2', 'face_motion_PC_3', 'face_motion_PC_4',
#        'image0', 'image1', 'image2', 'image3', 'image4', 'image5',
#        'image6', 'image7'], dtype=object)

# %%
data_to_plot
# Out:
#        timestamps  timestamp_index  kernel_outputs kernel_name
# 14831  1700.07352            14831        0.005601   pre_licks
# 14832  1700.16676            14832        0.015707   pre_licks
# 14833  1700.25999            14833       -0.003559   pre_licks
# 14834  1700.35322            14834       -0.004849   pre_licks
# 14835  1700.44645            14835       -0.000861   pre_licks
# ...           ...              ...             ...         ...
# 15040  1719.55915            15040        0.000000      image7
# 15041  1719.65238            15041        0.000000      image7
# 15042  1719.74561            15042        0.000000      image7
# 15043  1719.83884            15043        0.000000      image7
# 15044  1719.93208            15044        0.000000      image7
#
# [5564 rows x 4 columns]

# %%
kernel_names = [k for k in data_to_plot['kernel_name'].unique() if 'timestamp' not in k]
for kernel_name in kernel_names:
    data = data_to_plot

# %%
from scipy import stats

# %%
stats.percentileofscore(data_to_plot['kernel_outputs_abs'], 0.05, kind='strict')
# Out:
# 87.70668583752695

# %%
stats.percentileofscore?

# %%
self.kernel_df
# Out:
#        timestamps  timestamp_index  kernel_outputs kernel_name
# 0       317.35506                0        -0.00698   intercept
# 1       317.44829                1        -0.00698   intercept
# 2       317.54152                2        -0.00698   intercept
# 3       317.63475                3        -0.00698   intercept
# 4       317.72798                4        -0.00698   intercept
# ...           ...              ...             ...         ...
# 38645  3920.33302            38645         0.00000      image7
# 38646  3920.42625            38646         0.00000      image7
# 38647  3920.51949            38647         0.00000      image7
# 38648  3920.61272            38648         0.00000      image7
# 38649  3920.70596            38649         0.00000      image7
#
# [1082200 rows x 4 columns]

# %%
palette_df = pd.DataFrame({
    'kernel_name':self.kernel_df['kernel_name'].unique(),
    'kernel_color':vbp.generate_random_colors(
        len(self.kernel_df['kernel_name'].unique()), 
        lightness_range=(0.1,.65), 
        saturation_range=(0.5,1), 
        random_seed=3, 
        order_colors=False
    )
})
palette_df
# Out:
#           kernel_name                                       kernel_color
# 0           intercept  (0.009968179232284546, 0.4318454396151756, 0.6...
# 1                time  (0.48426790118158475, 0.33309050158442255, 0.9...
# 2           pre_licks  (0.4137999807436036, 0.9688847700993637, 0.224...
# 3          post_licks  (0.1397517039596199, 0.4541944469516509, 0.476...
# 4      pre_lick_bouts  (0.81719332260592, 0.10155867016996978, 0.5612...
# 5     post_lick_bouts  (0.481920893916228, 0.11580034545260803, 0.343...
# 6             rewards  (0.5612501698841906, 0.4440873501747524, 0.085...
# 7              change  (0.33029314839843393, 0.4083132647503653, 0.08...
# 8                hits  (0.6789280088196009, 0.22660815960415992, 0.02...
# 9              misses  (0.15134137035566975, 0.6935368245589338, 0.50...
# 10    correct_rejects  (0.4368155922682187, 0.1349005125505388, 0.068...
# 11          omissions  (0.08504345984556477, 0.34090791921992153, 0.2...
# 12  image_expectation  (0.1746674607160097, 0.21841481459414322, 0.59...
# 13            running  (0.2807634335013688, 0.6152312483394298, 0.116...
# 14              pupil  (0.11111150897863149, 0.061949374049525385, 0....
# 15   face_motion_PC_0  (0.07461241371998617, 0.4434636590760575, 0.88...
# 16   face_motion_PC_1  (0.5602710353088911, 0.12401350527899319, 0.05...
# 17   face_motion_PC_2  (0.061286300460343224, 0.35319592720639365, 0....
# 18   face_motion_PC_3  (0.2567951099949831, 0.480931804809178, 0.0774...
# 19   face_motion_PC_4  (0.050680506070947096, 0.21700131784198612, 0....
# 20             image0  (0.5438789129756644, 0.8593436498367062, 0.409...
# 21             image1  (0.20984988552665051, 0.08394018991704799, 0.8...
# 22             image2  (0.13074664183029527, 0.8655864115509352, 0.60...
# 23             image3  (0.6565845982915132, 0.6297254003369486, 0.199...
# 24             image4  (0.05603530197930082, 0.17884441636850917, 0.2...
# 25             image5  (0.22024595425873794, 0.08257602191569474, 0.2...
# 26             image6  (0.08122851639493285, 0.3040035643332314, 0.03...
# 27             image7  (0.2700706796429993, 0.4017274429879311, 0.004...

# %%
kernels_to_exclude_from_plot = ['intercept','time','model_task0','model_timing1D','model_bias','model_omissions1']
kernels_to_include_in_plot = [k for k in self.kernel_df['kernel_name'].unique() if k not in kernels_to_exclude_from_plot]
palette_df.query('kernel_name in @kernels_to_include_in_plot')['kernel_color'].to_list()
# Out:
# [(0.4137999807436036, 0.9688847700993637, 0.22423274929287418),
#  (0.1397517039596199, 0.4541944469516509, 0.4760417415021583),
#  (0.81719332260592, 0.10155867016996978, 0.5612238848757256),
#  (0.481920893916228, 0.11580034545260803, 0.3436157324075531),
#  (0.5612501698841906, 0.4440873501747524, 0.08592173812968296),
#  (0.33029314839843393, 0.4083132647503653, 0.08784587132580213),
#  (0.6789280088196009, 0.22660815960415992, 0.024527030435674946),
#  (0.15134137035566975, 0.6935368245589338, 0.5009810223217017),
#  (0.4368155922682187, 0.1349005125505388, 0.06895966501774281),
#  (0.08504345984556477, 0.34090791921992153, 0.274638857000833),
#  (0.1746674607160097, 0.21841481459414322, 0.5907711050831765),
#  (0.2807634335013688, 0.6152312483394298, 0.1167128372473154),
#  (0.11111150897863149, 0.061949374049525385, 0.9165059099477129),
#  (0.07461241371998617, 0.4434636590760575, 0.8855898003213547),
#  (0.5602710353088911, 0.12401350527899319, 0.05068910125492998),
#  (0.061286300460343224, 0.35319592720639365, 0.5125472298921565),
#  (0.2567951099949831, 0.480931804809178, 0.07745606906218389),
#  (0.050680506070947096, 0.21700131784198612, 0.13227869085193775),
#  (0.5438789129756644, 0.8593436498367062, 0.40941921695421835),
#  (0.20984988552665051, 0.08394018991704799, 0.8766850721250152),
#  (0.13074664183029527, 0.8655864115509352, 0.6030445531836113),
#  (0.6565845982915132, 0.6297254003369486, 0.19974555377053604),
#  (0.05603530197930082, 0.17884441636850917, 0.22378304962515597),
#  (0.22024595425873794, 0.08257602191569474, 0.28447107479370043),
#  (0.08122851639493285, 0.3040035643332314, 0.03821968673650822),
#  (0.2700706796429993, 0.4017274429879311, 0.004868864428334951)]

# %%
kernels_to_include_in_plot
# Out:
# ['pre_licks',
#  'post_licks',
#  'pre_lick_bouts',
#  'post_lick_bouts',
#  'rewards',
#  'change',
#  'hits',
#  'misses',
#  'correct_rejects',
#  'omissions',
#  'image_expectation',
#  'running',
#  'pupil',
#  'face_motion_PC_0',
#  'face_motion_PC_1',
#  'face_motion_PC_2',
#  'face_motion_PC_3',
#  'face_motion_PC_4',
#  'image0',
#  'image1',
#  'image2',
#  'image3',
#  'image4',
#  'image5',
#  'image6',
#  'image7']

# %%
glm.ophys_session_id
# Out:
# 994212056

# %%
db.get_well_known_files(glm.ophys_session_id)
# Out:
#                                   id        size  \
# name
# EyeDlcScreenMapping       1000887222    25128016
# EyeTracking Ellipses      1000886747    19672792
# EyeDlcOutputFile          1000882286   119135726
# RawBehaviorTrackingVideo   994279102  1617614094
# RawEyeTrackingVideo        994279101  5527879180
# OphysRigSync               994279100    11893373
# StimulusPickle             994279099    30169728
# OphysPlatformJson          994279088       10639
#
#                                                content_type  \
# name
# EyeDlcScreenMapping       application/x-hdf; charset=binary
# EyeTracking Ellipses      application/x-hdf; charset=binary
# EyeDlcOutputFile          application/x-hdf; charset=binary
# RawBehaviorTrackingVideo    video/x-msvideo; charset=binary
# RawEyeTrackingVideo         video/x-msvideo; charset=binary
# OphysRigSync              application/x-hdf; charset=binary
# StimulusPickle                 text/plain; charset=us-ascii
# OphysPlatformJson              text/plain; charset=us-ascii
#
#                                                                    filename  \
# name
# EyeDlcScreenMapping          994212056_eyetracking_dlc_to_screen_mapping.h5
# EyeTracking Ellipses                                   994212056_ellipse.h5
# EyeDlcOutputFile          994212056_video-1DeepCut_resnet50_universal_ey...
# RawBehaviorTrackingVideo                              994212056_video-0.avi
# RawEyeTrackingVideo                                   994212056_video-1.avi
# OphysRigSync                                                   994212056.h5
# StimulusPickle                                                994212056.pkl
# OphysPlatformJson                                   994212056_platform.json
#
#                                          created_at  \
# name
# EyeDlcScreenMapping      2020-01-18 13:17:41.528342
# EyeTracking Ellipses     2020-01-18 13:12:34.780929
# EyeDlcOutputFile         2020-01-18 12:23:46.723204
# RawBehaviorTrackingVideo 2019-12-14 09:06:16.525153
# RawEyeTrackingVideo      2019-12-14 09:06:16.483349
# OphysRigSync             2019-12-14 09:06:16.438501
# StimulusPickle           2019-12-14 09:06:16.390789
# OphysPlatformJson        2019-12-14 09:06:15.934350
#
#                                          updated_at  \
# name
# EyeDlcScreenMapping      2020-01-18 13:17:41.528342
# EyeTracking Ellipses     2020-01-18 13:12:34.780929
# EyeDlcOutputFile         2020-01-18 12:23:46.723204
# RawBehaviorTrackingVideo 2019-12-14 09:06:16.525153
# RawEyeTrackingVideo      2019-12-14 09:06:16.483349
# OphysRigSync             2019-12-14 09:06:16.438501
# StimulusPickle           2019-12-14 09:06:16.390789
# OphysPlatformJson        2019-12-14 09:06:15.934350
#
#                                                           storage_directory  \
# name
# EyeDlcScreenMapping       /allen/programs/braintv/production/visualbehav...
# EyeTracking Ellipses      /allen/programs/braintv/production/visualbehav...
# EyeDlcOutputFile          /allen/programs/braintv/production/visualbehav...
# RawBehaviorTrackingVideo  /allen/programs/braintv/production/visualbehav...
# RawEyeTrackingVideo       /allen/programs/braintv/production/visualbehav...
# OphysRigSync              /allen/programs/braintv/production/visualbehav...
# StimulusPickle            /allen/programs/braintv/production/visualbehav...
# OphysPlatformJson         /allen/programs/braintv/production/visualbehav...
#
#                           well_known_file_type_id file_source_id published_at  \
# name
# EyeDlcScreenMapping                     916857994           None         None
# EyeTracking Ellipses                    914623492           None         None
# EyeDlcOutputFile                        990460508           None         None
# RawBehaviorTrackingVideo                695808672           None         None
# RawEyeTrackingVideo                     695808172           None         None
# OphysRigSync                            610487713           None         None
# StimulusPickle                          610487715           None         None
# OphysPlatformJson                       746251277           None         None
#
#                          workflow_state  attachable_id attachable_type  \
# name
# EyeDlcScreenMapping                None      994212056    OphysSession
# EyeTracking Ellipses               None      994212056    OphysSession
# EyeDlcOutputFile                   None      994212056    OphysSession
# RawBehaviorTrackingVideo           None      994212056    OphysSession
# RawEyeTrackingVideo                None      994212056    OphysSession
# OphysRigSync                       None      994212056    OphysSession
# StimulusPickle                     None      994212056    OphysSession
# OphysPlatformJson                  None      994212056    OphysSession
#
#                                  id                 created_at  \
# name
# EyeDlcScreenMapping       916857994 2019-08-03 16:26:11.202016
# EyeTracking Ellipses      914623492 2019-07-31 13:22:05.683874
# EyeDlcOutputFile          990460508 2019-11-26 16:47:20.006823
# RawBehaviorTrackingVideo  695808672 2018-05-09 17:38:24.006153
# RawEyeTrackingVideo       695808172 2018-05-09 17:38:12.733419
# OphysRigSync              610487713 2017-08-18 02:02:26.580050
# StimulusPickle            610487715 2017-08-18 02:02:27.885973
# OphysPlatformJson         746251277 2018-09-07 02:13:00.160665
#
#                                          updated_at
# name
# EyeDlcScreenMapping      2019-08-03 16:26:11.202016
# EyeTracking Ellipses     2019-07-31 13:22:05.683874
# EyeDlcOutputFile         2019-11-26 16:47:20.006823
# RawBehaviorTrackingVideo 2018-05-09 17:38:24.006153
# RawEyeTrackingVideo      2018-05-09 17:38:12.733419
# OphysRigSync             2017-08-18 02:02:26.580050
# StimulusPickle           2017-08-18 02:02:27.885973
# OphysPlatformJson        2018-09-07 02:13:00.160665

# %%
# %%time
frame = 128387
mean_frame = np.mean(self.real_2p_movie[frame-1000:frame+1000,:,:], axis=0)

dff = (self.real_2p_movie[frame,:,:]-mean_frame)/mean_frame
dff[np.where(pd.isnull(dff))] = 0
dff

fig,ax=plt.subplots(1,2,figsize=(15,10))
ax[0].imshow(self.real_2p_movie[frame,:,:])

ax[1].imshow(dff,clim=[-1,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/.conda/envs/visual_behavior/lib/python3.8/site-packages/h5py-2.10.0-py3.8-linux-x86_64.egg/h5py/_hl/dataset.py in __getitem__(self, args)
#     551
#     552         # Perform the dataspace selection.
# --> 553         selection = sel.select(self.shape, args, dsid=self.id)
#     554
#     555         if selection.nselect == 0:
#
# ~/.conda/envs/visual_behavior/lib/python3.8/site-packages/h5py-2.10.0-py3.8-linux-x86_64.egg/h5py/_hl/selections.py in select(shape, args, dsid)
#      92
#      93     sel = SimpleSelection(shape)
# ---> 94     sel[args]
#      95     return sel
#      96
#
# ~/.conda/envs/visual_behavior/lib/python3.8/site-packages/h5py-2.10.0-py3.8-linux-x86_64.egg/h5py/_hl/selections.py in __getitem__(self, args)
#     259             return self
#     260
# --> 261         start, count, step, scalar = _handle_simple(self.shape,args)
#     262
#     263         self._id.select_hyperslab(start, count, step)
#
# ~/.conda/envs/visual_behavior/lib/python3.8/site-packages/h5py-2.10.0-py3.8-linux-x86_64.egg/h5py/_hl/selections.py in _handle_simple(shape, args)
#     464         else:
#     465             try:
# --> 466                 x,y,z = _translate_int(int(arg), length)
#     467                 s = True
#     468             except TypeError:
#
# ~/.conda/envs/visual_behavior/lib/python3.8/site-packages/h5py-2.10.0-py3.8-linux-x86_64.egg/h5py/_hl/selections.py in _translate_int(exp, length)
#     484
#     485     if not 0<=exp<length:
# --> 486         raise ValueError("Index (%s) out of range (0-%s)" % (exp, length-1))
#     487
#     488     return exp, 1, 1
#
# ValueError: Index (128387) out of range (0-48305)

# %%
cell_specimen_id=1022738497
glm.df_full.query('cell_specimen_id == @cell_specimen_id and dff>1.8')['dff']
# Out:
# 128387     1.809695
# 1131323    1.837492
# Name: dff, dtype: float64

# %%
np.shape(self.real_2p_movie)
# Out:
# (48306, 512, 512)

# %%
behavior_movie_path = 
behavior_movie =

# %%
def get_movie_filepath(session_id, session_type='OphysSession', movie_type='RawBehaviorTrackingVideo'):
    well_known_files = db.get_well_known_files(session_id, session_type)
    behavior_video_path = ''.join(well_known_files.loc[movie_type][[
                                  'storage_directory', 'filename']].tolist())
    return behavior_video_path

# %%
def get_sync_data(session_id, session_type='OphysSession'):
    sync_key_map = {
        'OphysSession': 'OphysRigSync',
        'EcephysSession': 'EcephysRigSync',
    }
    well_known_files = db.get_well_known_files(session_id, session_type)
    sync_path = ''.join(well_known_files.loc[sync_key_map[session_type]][[
                        'storage_directory', 'filename']].tolist())
    sync_data = vbu.get_sync_data(sync_path)
    return sync_data

# %%
sync_data = get_sync_data(glm.ophys_session_id)
sync_data
# Out:
# {'2p_vsync_rising': array([  17.28783,   17.31113,   17.33443, ..., 4520.90018, 4520.92349,
#         4520.9468 ]),
#  '2p_vsync_falling': array([  17.30904,   17.33234,   17.35565, ..., 4520.9214 , 4520.94471,
#         4520.96802]),
#  'stim_vsync_rising': array([  17.29019,   17.3051 ,   17.32164, ..., 4520.86694, 4520.88342,
#         4520.90365]),
#  'stim_vsync_falling': array([  17.30449,   17.32113,   17.33782, ..., 4520.8662 , 4520.88286,
#         4520.89955]),
#  'stim_photodiode_rising': array([  16.92468,   17.09151,   17.25828, ..., 4521.03681, 4521.2036 ,
#         4521.37043]),
#  'stim_photodiode_falling': array([  17.00568,   17.17247,   17.33927, ..., 4521.11787, 4521.28466,
#         4521.4848 ]),
#  'acq_trigger_rising': array([17.28778]),
#  'acq_trigger_falling': array([4520.90389]),
#  'cam1_exposure_rising': array([8.31600000e-02, 1.06380000e-01, 1.37270000e-01, ...,
#         4.54906379e+03, 4.54908212e+03, 4.54911938e+03]),
#  'cam1_exposure_falling': array([8.69900000e-02, 1.35450000e-01, 1.53670000e-01, ...,
#         4.54908149e+03, 4.54911794e+03, 4.54914813e+03]),
#  'cam2_exposure_rising': array([1.36790000e-01, 1.50030000e-01, 1.76970000e-01, ...,
#         4.54941931e+03, 4.54944718e+03, 4.54949273e+03]),
#  'cam2_exposure_falling': array([1.37710000e-01, 1.70940000e-01, 2.06510000e-01, ...,
#         4.54944639e+03, 4.54948649e+03, 4.54951303e+03]),
#  'lick_sensor_rising': array([2.90262000e+00, 6.78195000e+00, 6.92987000e+00, ...,
#         4.46651465e+03, 4.46765057e+03, 4.49642843e+03]),
#  'lick_sensor_falling': array([2.95968000e+00, 6.83428000e+00, 6.98222000e+00, ...,
#         4.46656720e+03, 4.46770314e+03, 4.49648098e+03])}

# %%
behavior_movie = vbu.Movie(get_movie_filepath(glm.ophys_session_id, movie_type='RawBehaviorTrackingVideo'), sync_timestamps=sync_data['cam1_exposure_rising'])
eye_movie = vbu.Movie(get_movie_filepath(glm.ophys_session_id, movie_type='RawEyeTrackingVideo'), sync_timestamps=sync_data['cam2_exposure_rising'])

# %%
fig,ax=plt.subplots()
frame = behavior_movie.get_frame(time=1710)[:,:,0]
frame_n1 = behavior_movie.get_frame(time=1710-0.1)[:,:,0]
frame_p1 = behavior_movie.get_frame(time=1710+0.1)[:,:,0]
frame_n2 = behavior_movie.get_frame(time=1710-0.2)[:,:,0]
frame_p2 = behavior_movie.get_frame(time=1710+0.2)[:,:,0]
p99 = np.percentile(frame, 99)
ax.imshow(frame,clim=[0,p99],cmap='gray')

# %%
np.percentile(np.hstack((frame.flatten(),frame_n1.flatten(),frame_p1.flatten(),frame_n2.flatten(),frame_p2.flatten())),99)
# Out:
# 73.0

# %%
np.shape(behavior_movie.get_frame(time=1710))
# Out:
# (480, 640, 3)

# %%
eye_movie.get_frame(time=1710)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-261-291716ac3a75> in <module>
# ----> 1 eye_movie.get_frame(time=1710)
#
# ~/Code/visual_behavior_analysis/visual_behavior/utilities.py in get_frame(self, frame, time, timestamps)
#     327     def get_frame(self, frame=None, time=None, timestamps='sync'):
#     328         if time and timestamps == 'sync':
# --> 329             assert self.sync_timestamps is not None, 'sync timestamps do not exist'
#     330             timestamps = self.sync_timestamps
#     331         elif time and timestamps == 'file':
#
# AssertionError: sync timestamps do not exist

# %%
fig,ax=plt.subplots(figsize=(5,15))
gvt.plot_dropout_summary(self.results_summary, self.cell_specimen_id, ax)

# %%
self.results_summary
# Out:
# type             dropout  absolute_change_from_full  variance_explained  \
# 0                   Full                   0.000000            0.008935
# 1             all-images                  -0.000383            0.008552
# 2             behavioral                  -0.003169            0.005766
# 3                 change                   0.000199            0.009134
# 4     change_and_rewards                   0.000357            0.009292
# ...                  ...                        ...                 ...
# 3867       single-visual                  -0.093935            0.000700
# 3868                task                  -0.006172            0.088462
# 3869                time                   0.000092            0.094726
# 3870          trial_type                  -0.000167            0.094467
# 3871              visual                  -0.000888            0.093746
#
# type  variance_explained_full  fraction_change_from_full  cell_specimen_id
# 0                    0.008935                   0.000000        1022738347
# 1                    0.008935                  -0.042877        1022738347
# 2                    0.008935                  -0.354685        1022738347
# 3                    0.008935                   0.000000        1022738347
# 4                    0.008935                   0.000000        1022738347
# ...                       ...                        ...               ...
# 3867                 0.094634                   0.000000        1022739044
# 3868                 0.094634                  -0.065220        1022739044
# 3869                 0.094634                   0.000000        1022739044
# 3870                 0.094634                  -0.001764        1022739044
# 3871                 0.094634                  -0.009388        1022739044
#
# [3872 rows x 6 columns]

# %%
data_to_plot = (
        self.results_summary
        .query('cell_specimen_id == @cell_specimen_id')
        .sort_values(by='fraction_change_from_full', ascending=False)
    ).copy().reset_index(drop=True)
data_to_plot
# Out:
# type                   dropout  absolute_change_from_full  variance_explained  \
# 0                         Full                   0.000000            0.665450
# 1                    intercept                   0.000695            0.666145
# 2                       image5                   0.000010            0.665460
# 3                       image4                   0.000014            0.665465
# 4                       image3                   0.000198            0.665648
# ..                         ...                        ...                 ...
# 83            single-cognitive                  -0.217265            0.448185
# 84           single-post_licks                  -0.208417            0.457033
# 85    single-licking_each_lick                  -0.173061            0.492390
# 86              single-licking                  -0.146156            0.519294
# 87           single-behavioral                  -0.058527            0.606923
#
# type  variance_explained_full  fraction_change_from_full  cell_specimen_id
# 0                     0.66545                   0.000000        1022738497
# 1                     0.66545                   0.000000        1022738497
# 2                     0.66545                   0.000000        1022738497
# 3                     0.66545                   0.000000        1022738497
# 4                     0.66545                   0.000000        1022738497
# ..                        ...                        ...               ...
# 83                    0.66545                  -0.673507        1022738497
# 84                    0.66545                  -0.686802        1022738497
# 85                    0.66545                  -0.739934        1022738497
# 86                    0.66545                  -0.780365        1022738497
# 87                    0.66545                  -0.912049        1022738497
#
# [88 rows x 6 columns]

# %%
fig,ax=plt.subplots(figsize=(5,15))
sns.barplot(
    data = data_to_plot,
    x = 'fraction_change_from_full',
    y = 'dropout',
    ax=ax,
    # palette=palette
)

# %%
dropouts = data_to_plot.dropout.unique()
single_dropouts = [d for d in dropouts if d.startswith('single-')]
combined_dropouts = [d.split('single-')[1] for d in singles]

# %%
gat.generate_results_summary(self.glm)
# Out:
#                  dropout  absolute_change_from_full  variance_explained  \
# 0                   Full                   0.000000            0.008935
# 1             all-images                  -0.000383            0.008552
# 2             behavioral                  -0.003169            0.005766
# 3                 change                   0.000199            0.009134
# 4     change_and_rewards                   0.000357            0.009292
# ...                  ...                        ...                 ...
# 3867       single-visual                  -0.093935            0.000700
# 3868                task                  -0.006172            0.088462
# 3869                time                   0.000092            0.094726
# 3870          trial_type                  -0.000167            0.094467
# 3871              visual                  -0.000888            0.093746
#
#       variance_explained_full  fraction_change_from_full  cell_specimen_id  \
# 0                    0.008935                   0.000000        1022738347
# 1                    0.008935                  -0.042877        1022738347
# 2                    0.008935                  -0.354685        1022738347
# 3                    0.008935                   0.000000        1022738347
# 4                    0.008935                   0.000000        1022738347
# ...                       ...                        ...               ...
# 3867                 0.094634                   0.000000        1022739044
# 3868                 0.094634                  -0.065220        1022739044
# 3869                 0.094634                   0.000000        1022739044
# 3870                 0.094634                  -0.001764        1022739044
# 3871                 0.094634                  -0.009388        1022739044
#
#       adj_fraction_change_from_full  adj_variance_explained  \
# 0                          0.000000                0.008935
# 1                         -0.037372                0.010430
# 2                         -0.353433                0.005776
# 3                          0.000000                0.001981
# 4                          0.000000                0.010251
# ...                             ...                     ...
# 3867                       0.000000                0.000700
# 3868                      -0.063397                0.151349
# 3869                       0.000000                0.094726
# 3870                       0.000000                0.000000
# 3871                      -0.009388                0.093746
#
#       adj_variance_explained_full
# 0                        0.008935
# 1                        0.010835
# 2                        0.008933
# 3                        0.001513
# 4                        0.009048
# ...                           ...
# 3867                     0.094634
# 3868                     0.161594
# 3869                     0.094634
# 3870                     0.000000
# 3871                     0.094634
#
# [3872 rows x 9 columns]

# %%
data_to_plot = (
    gat.generate_results_summary(self.glm)
    .query('cell_specimen_id == @cell_specimen_id')
    .sort_values(by='adj_fraction_change_from_full', ascending=False)
).copy().reset_index(drop=True)

dropouts = data_to_plot.dropout.unique()
single_dropouts = [d for d in dropouts if d.startswith('single-')]
combined_dropouts = [d.split('single-')[1] for d in single_dropouts]

for idx,row in data_to_plot.iterrows():
    if row['dropout'] in single_dropouts:
        data_to_plot.at[idx,'dropout_type']='single'
        data_to_plot.at[idx,'dropout_simple']=row['dropout'].split('single-')[1]
    elif row['dropout'] in combined_dropouts:
        data_to_plot.at[idx,'dropout_type']='combined'
        data_to_plot.at[idx,'dropout_simple']=row['dropout']

# %%
yorder = data_to_plot.query('dropout_type == "single"').sort_values(by='adj_fraction_change_from_full',ascending=False)['dropout_simple'].values
yorder
# Out:
# array(['image4', 'correct_rejects', 'misses', 'omissions',
#        'post_lick_bouts', 'pre_lick_bouts', 'trial_type', 'licking_bouts',
#        'visual', 'time', 'all-images', 'image_expectation',
#        'face_motion_PC_2', 'image0', 'image1', 'image2', 'image3',
#        'image5', 'image6', 'image7', 'expectation', 'pupil_and_omissions',
#        'face_motion_PC_1', 'pupil', 'face_motion_PC_3',
#        'face_motion_PC_0', 'pre_licks', 'change', 'post_licks',
#        'licking_each_lick', 'licking', 'rewards', 'face_motion_PC_4',
#        'hits_and_rewards', 'change_and_rewards', 'task', 'cognitive',
#        'running_and_omissions', 'running', 'pupil_and_running',
#        'face_motion_energy', 'behavioral', 'hits'], dtype=object)

# %%
fig,ax=plt.subplots(figsize=(5,15))
gvt.plot_dropout_summary(gat.generate_results_summary(self.glm), cell_specimen_id, ax)

# %%
gat.generate_results_summary(self.glm).reset_index()
# Out:
# type             dropout  absolute_change_from_full  variance_explained  \
# 0                   Full                   0.000000            0.008935
# 1             all-images                  -0.000383            0.008552
# 2             behavioral                  -0.003169            0.005766
# 3                 change                   0.000199            0.009134
# 4     change_and_rewards                   0.000357            0.009292
# ...                  ...                        ...                 ...
# 3867       single-visual                  -0.093935            0.000700
# 3868                task                  -0.006172            0.088462
# 3869                time                   0.000092            0.094726
# 3870          trial_type                  -0.000167            0.094467
# 3871              visual                  -0.000888            0.093746
#
# type  variance_explained_full  fraction_change_from_full  cell_specimen_id
# 0                    0.008935                   0.000000        1022738347
# 1                    0.008935                  -0.042877        1022738347
# 2                    0.008935                  -0.354685        1022738347
# 3                    0.008935                   0.000000        1022738347
# 4                    0.008935                   0.000000        1022738347
# ...                       ...                        ...               ...
# 3867                 0.094634                   0.000000        1022739044
# 3868                 0.094634                  -0.065220        1022739044
# 3869                 0.094634                   0.000000        1022739044
# 3870                 0.094634                  -0.001764        1022739044
# 3871                 0.094634                  -0.009388        1022739044
#
# [3872 rows x 6 columns]

# %%
glm.results.loc[1022739044]['task__avg_cv_adjvar_test']
# Out:
# 0.15134909752915315

# %%
test_cols = [col for col in glm.results.columns if ((not col.endswith('train'))&('adj' in col))]
test_cols
# Out:
# ['Full__avg_cv_adjvar_test',
#  'Full__avg_cv_adjvar_test_full_comparison',
#  'Full__adj_dropout',
#  'intercept__avg_cv_adjvar_test',
#  'intercept__avg_cv_adjvar_test_full_comparison',
#  'intercept__adj_dropout',
#  'time__avg_cv_adjvar_test',
#  'time__avg_cv_adjvar_test_full_comparison',
#  'time__adj_dropout',
#  'pre_licks__avg_cv_adjvar_test',
#  'pre_licks__avg_cv_adjvar_test_full_comparison',
#  'pre_licks__adj_dropout',
#  'post_licks__avg_cv_adjvar_test',
#  'post_licks__avg_cv_adjvar_test_full_comparison',
#  'post_licks__adj_dropout',
#  'pre_lick_bouts__avg_cv_adjvar_test',
#  'pre_lick_bouts__avg_cv_adjvar_test_full_comparison',
#  'pre_lick_bouts__adj_dropout',
#  'post_lick_bouts__avg_cv_adjvar_test',
#  'post_lick_bouts__avg_cv_adjvar_test_full_comparison',
#  'post_lick_bouts__adj_dropout',
#  'rewards__avg_cv_adjvar_test',
#  'rewards__avg_cv_adjvar_test_full_comparison',
#  'rewards__adj_dropout',
#  'change__avg_cv_adjvar_test',
#  'change__avg_cv_adjvar_test_full_comparison',
#  'change__adj_dropout',
#  'hits__avg_cv_adjvar_test',
#  'hits__avg_cv_adjvar_test_full_comparison',
#  'hits__adj_dropout',
#  'misses__avg_cv_adjvar_test',
#  'misses__avg_cv_adjvar_test_full_comparison',
#  'misses__adj_dropout',
#  'correct_rejects__avg_cv_adjvar_test',
#  'correct_rejects__avg_cv_adjvar_test_full_comparison',
#  'correct_rejects__adj_dropout',
#  'omissions__avg_cv_adjvar_test',
#  'omissions__avg_cv_adjvar_test_full_comparison',
#  'omissions__adj_dropout',
#  'image_expectation__avg_cv_adjvar_test',
#  'image_expectation__avg_cv_adjvar_test_full_comparison',
#  'image_expectation__adj_dropout',
#  'running__avg_cv_adjvar_test',
#  'running__avg_cv_adjvar_test_full_comparison',
#  'running__adj_dropout',
#  'pupil__avg_cv_adjvar_test',
#  'pupil__avg_cv_adjvar_test_full_comparison',
#  'pupil__adj_dropout',
#  'face_motion_PC_0__avg_cv_adjvar_test',
#  'face_motion_PC_0__avg_cv_adjvar_test_full_comparison',
#  'face_motion_PC_0__adj_dropout',
#  'face_motion_PC_1__avg_cv_adjvar_test',
#  'face_motion_PC_1__avg_cv_adjvar_test_full_comparison',
#  'face_motion_PC_1__adj_dropout',
#  'face_motion_PC_2__avg_cv_adjvar_test',
#  'face_motion_PC_2__avg_cv_adjvar_test_full_comparison',
#  'face_motion_PC_2__adj_dropout',
#  'face_motion_PC_3__avg_cv_adjvar_test',
#  'face_motion_PC_3__avg_cv_adjvar_test_full_comparison',
#  'face_motion_PC_3__adj_dropout',
#  'face_motion_PC_4__avg_cv_adjvar_test',
#  'face_motion_PC_4__avg_cv_adjvar_test_full_comparison',
#  'face_motion_PC_4__adj_dropout',
#  'image0__avg_cv_adjvar_test',
#  'image0__avg_cv_adjvar_test_full_comparison',
#  'image0__adj_dropout',
#  'image1__avg_cv_adjvar_test',
#  'image1__avg_cv_adjvar_test_full_comparison',
#  'image1__adj_dropout',
#  'image2__avg_cv_adjvar_test',
#  'image2__avg_cv_adjvar_test_full_comparison',
#  'image2__adj_dropout',
#  'image3__avg_cv_adjvar_test',
#  'image3__avg_cv_adjvar_test_full_comparison',
#  'image3__adj_dropout',
#  'image4__avg_cv_adjvar_test',
#  'image4__avg_cv_adjvar_test_full_comparison',
#  'image4__adj_dropout',
#  'image5__avg_cv_adjvar_test',
#  'image5__avg_cv_adjvar_test_full_comparison',
#  'image5__adj_dropout',
#  'image6__avg_cv_adjvar_test',
#  'image6__avg_cv_adjvar_test_full_comparison',
#  'image6__adj_dropout',
#  'image7__avg_cv_adjvar_test',
#  'image7__avg_cv_adjvar_test_full_comparison',
#  'image7__adj_dropout',
#  'face_motion_energy__avg_cv_adjvar_test',
#  'face_motion_energy__avg_cv_adjvar_test_full_comparison',
#  'face_motion_energy__adj_dropout',
#  'all-images__avg_cv_adjvar_test',
#  'all-images__avg_cv_adjvar_test_full_comparison',
#  'all-images__adj_dropout',
#  'visual__avg_cv_adjvar_test',
#  'visual__avg_cv_adjvar_test_full_comparison',
#  'visual__adj_dropout',
#  'behavioral__avg_cv_adjvar_test',
#  'behavioral__avg_cv_adjvar_test_full_comparison',
#  'behavioral__adj_dropout',
#  'licking__avg_cv_adjvar_test',
#  'licking__avg_cv_adjvar_test_full_comparison',
#  'licking__adj_dropout',
#  'licking_bouts__avg_cv_adjvar_test',
#  'licking_bouts__avg_cv_adjvar_test_full_comparison',
#  'licking_bouts__adj_dropout',
#  'licking_each_lick__avg_cv_adjvar_test',
#  'licking_each_lick__avg_cv_adjvar_test_full_comparison',
#  'licking_each_lick__adj_dropout',
#  'pupil_and_running__avg_cv_adjvar_test',
#  'pupil_and_running__avg_cv_adjvar_test_full_comparison',
#  'pupil_and_running__adj_dropout',
#  'pupil_and_omissions__avg_cv_adjvar_test',
#  'pupil_and_omissions__avg_cv_adjvar_test_full_comparison',
#  'pupil_and_omissions__adj_dropout',
#  'running_and_omissions__avg_cv_adjvar_test',
#  'running_and_omissions__avg_cv_adjvar_test_full_comparison',
#  'running_and_omissions__adj_dropout',
#  'task__avg_cv_adjvar_test',
#  'task__avg_cv_adjvar_test_full_comparison',
#  'task__adj_dropout',
#  'trial_type__avg_cv_adjvar_test',
#  'trial_type__avg_cv_adjvar_test_full_comparison',
#  'trial_type__adj_dropout',
#  'change_and_rewards__avg_cv_adjvar_test',
#  'change_and_rewards__avg_cv_adjvar_test_full_comparison',
#  'change_and_rewards__adj_dropout',
#  'hits_and_rewards__avg_cv_adjvar_test',
#  'hits_and_rewards__avg_cv_adjvar_test_full_comparison',
#  'hits_and_rewards__adj_dropout',
#  'expectation__avg_cv_adjvar_test',
#  'expectation__avg_cv_adjvar_test_full_comparison',
#  'expectation__adj_dropout',
#  'cognitive__avg_cv_adjvar_test',
#  'cognitive__avg_cv_adjvar_test_full_comparison',
#  'cognitive__adj_dropout',
#  'single-time__avg_cv_adjvar_test',
#  'single-time__avg_cv_adjvar_test_full_comparison',
#  'single-time__adj_dropout',
#  'single-pre_licks__avg_cv_adjvar_test',
#  'single-pre_licks__avg_cv_adjvar_test_full_comparison',
#  'single-pre_licks__adj_dropout',
#  'single-post_licks__avg_cv_adjvar_test',
#  'single-post_licks__avg_cv_adjvar_test_full_comparison',
#  'single-post_licks__adj_dropout',
#  'single-pre_lick_bouts__avg_cv_adjvar_test',
#  'single-pre_lick_bouts__avg_cv_adjvar_test_full_comparison',
#  'single-pre_lick_bouts__adj_dropout',
#  'single-post_lick_bouts__avg_cv_adjvar_test',
#  'single-post_lick_bouts__avg_cv_adjvar_test_full_comparison',
#  'single-post_lick_bouts__adj_dropout',
#  'single-rewards__avg_cv_adjvar_test',
#  'single-rewards__avg_cv_adjvar_test_full_comparison',
#  'single-rewards__adj_dropout',
#  'single-change__avg_cv_adjvar_test',
#  'single-change__avg_cv_adjvar_test_full_comparison',
#  'single-change__adj_dropout',
#  'single-hits__avg_cv_adjvar_test',
#  'single-hits__avg_cv_adjvar_test_full_comparison',
#  'single-hits__adj_dropout',
#  'single-misses__avg_cv_adjvar_test',
#  'single-misses__avg_cv_adjvar_test_full_comparison',
#  'single-misses__adj_dropout',
#  'single-correct_rejects__avg_cv_adjvar_test',
#  'single-correct_rejects__avg_cv_adjvar_test_full_comparison',
#  'single-correct_rejects__adj_dropout',
#  'single-omissions__avg_cv_adjvar_test',
#  'single-omissions__avg_cv_adjvar_test_full_comparison',
#  'single-omissions__adj_dropout',
#  'single-image_expectation__avg_cv_adjvar_test',
#  'single-image_expectation__avg_cv_adjvar_test_full_comparison',
#  'single-image_expectation__adj_dropout',
#  'single-running__avg_cv_adjvar_test',
#  'single-running__avg_cv_adjvar_test_full_comparison',
#  'single-running__adj_dropout',
#  'single-pupil__avg_cv_adjvar_test',
#  'single-pupil__avg_cv_adjvar_test_full_comparison',
#  'single-pupil__adj_dropout',
#  'single-face_motion_PC_0__avg_cv_adjvar_test',
#  'single-face_motion_PC_0__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_PC_0__adj_dropout',
#  'single-face_motion_PC_1__avg_cv_adjvar_test',
#  'single-face_motion_PC_1__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_PC_1__adj_dropout',
#  'single-face_motion_PC_2__avg_cv_adjvar_test',
#  'single-face_motion_PC_2__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_PC_2__adj_dropout',
#  'single-face_motion_PC_3__avg_cv_adjvar_test',
#  'single-face_motion_PC_3__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_PC_3__adj_dropout',
#  'single-face_motion_PC_4__avg_cv_adjvar_test',
#  'single-face_motion_PC_4__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_PC_4__adj_dropout',
#  'single-image0__avg_cv_adjvar_test',
#  'single-image0__avg_cv_adjvar_test_full_comparison',
#  'single-image0__adj_dropout',
#  'single-image1__avg_cv_adjvar_test',
#  'single-image1__avg_cv_adjvar_test_full_comparison',
#  'single-image1__adj_dropout',
#  'single-image2__avg_cv_adjvar_test',
#  'single-image2__avg_cv_adjvar_test_full_comparison',
#  'single-image2__adj_dropout',
#  'single-image3__avg_cv_adjvar_test',
#  'single-image3__avg_cv_adjvar_test_full_comparison',
#  'single-image3__adj_dropout',
#  'single-image4__avg_cv_adjvar_test',
#  'single-image4__avg_cv_adjvar_test_full_comparison',
#  'single-image4__adj_dropout',
#  'single-image5__avg_cv_adjvar_test',
#  'single-image5__avg_cv_adjvar_test_full_comparison',
#  'single-image5__adj_dropout',
#  'single-image6__avg_cv_adjvar_test',
#  'single-image6__avg_cv_adjvar_test_full_comparison',
#  'single-image6__adj_dropout',
#  'single-image7__avg_cv_adjvar_test',
#  'single-image7__avg_cv_adjvar_test_full_comparison',
#  'single-image7__adj_dropout',
#  'single-face_motion_energy__avg_cv_adjvar_test',
#  'single-face_motion_energy__avg_cv_adjvar_test_full_comparison',
#  'single-face_motion_energy__adj_dropout',
#  'single-all-images__avg_cv_adjvar_test',
#  'single-all-images__avg_cv_adjvar_test_full_comparison',
#  'single-all-images__adj_dropout',
#  'single-visual__avg_cv_adjvar_test',
#  'single-visual__avg_cv_adjvar_test_full_comparison',
#  'single-visual__adj_dropout',
#  'single-behavioral__avg_cv_adjvar_test',
#  'single-behavioral__avg_cv_adjvar_test_full_comparison',
#  'single-behavioral__adj_dropout',
#  'single-licking__avg_cv_adjvar_test',
#  'single-licking__avg_cv_adjvar_test_full_comparison',
#  'single-licking__adj_dropout',
#  'single-licking_bouts__avg_cv_adjvar_test',
#  'single-licking_bouts__avg_cv_adjvar_test_full_comparison',
#  'single-licking_bouts__adj_dropout',
#  'single-licking_each_lick__avg_cv_adjvar_test',
#  'single-licking_each_lick__avg_cv_adjvar_test_full_comparison',
#  'single-licking_each_lick__adj_dropout',
#  'single-pupil_and_running__avg_cv_adjvar_test',
#  'single-pupil_and_running__avg_cv_adjvar_test_full_comparison',
#  'single-pupil_and_running__adj_dropout',
#  'single-pupil_and_omissions__avg_cv_adjvar_test',
#  'single-pupil_and_omissions__avg_cv_adjvar_test_full_comparison',
#  'single-pupil_and_omissions__adj_dropout',
#  'single-running_and_omissions__avg_cv_adjvar_test',
#  'single-running_and_omissions__avg_cv_adjvar_test_full_comparison',
#  'single-running_and_omissions__adj_dropout',
#  'single-task__avg_cv_adjvar_test',
#  'single-task__avg_cv_adjvar_test_full_comparison',
#  'single-task__adj_dropout',
#  'single-trial_type__avg_cv_adjvar_test',
#  'single-trial_type__avg_cv_adjvar_test_full_comparison',
#  'single-trial_type__adj_dropout',
#  'single-change_and_rewards__avg_cv_adjvar_test',
#  'single-change_and_rewards__avg_cv_adjvar_test_full_comparison',
#  'single-change_and_rewards__adj_dropout',
#  'single-hits_and_rewards__avg_cv_adjvar_test',
#  'single-hits_and_rewards__avg_cv_adjvar_test_full_comparison',
#  'single-hits_and_rewards__adj_dropout',
#  'single-expectation__avg_cv_adjvar_test',
#  'single-expectation__avg_cv_adjvar_test_full_comparison',
#  'single-expectation__adj_dropout',
#  'single-cognitive__avg_cv_adjvar_test',
#  'single-cognitive__avg_cv_adjvar_test_full_comparison',
#  'single-cognitive__adj_dropout']

# %%
cell_specimen_id = 1022739044
results_summary = pd.DataFrame(glm.results.loc[cell_specimen_id][test_cols]).reset_index().rename(columns={cell_specimen_id:'variance_explained','index':'dropout_name'})


for idx,row in results_summary.iterrows():
    results_summary.at[idx,'dropout'] = row['dropout_name'].split('__')[0]
    results_summary.at[idx,'type'] = row['dropout_name'].split('__')[1]

results_summary
# Out:
#                                           dropout_name  variance_explained  \
# 0                             Full__avg_cv_adjvar_test            0.094634
# 1             Full__avg_cv_adjvar_test_full_comparison            0.094634
# 2                                    Full__adj_dropout           -0.000000
# 3                        intercept__avg_cv_adjvar_test            0.094186
# 4        intercept__avg_cv_adjvar_test_full_comparison            0.094634
# ..                                                 ...                 ...
# 259  single-expectation__avg_cv_adjvar_test_full_co...            0.094680
# 260                    single-expectation__adj_dropout            0.000000
# 261               single-cognitive__avg_cv_adjvar_test            0.065473
# 262  single-cognitive__avg_cv_adjvar_test_full_comp...            0.161594
# 263                      single-cognitive__adj_dropout           -0.405172
#
#                 dropout                                type
# 0                  Full                  avg_cv_adjvar_test
# 1                  Full  avg_cv_adjvar_test_full_comparison
# 2                  Full                         adj_dropout
# 3             intercept                  avg_cv_adjvar_test
# 4             intercept  avg_cv_adjvar_test_full_comparison
# ..                  ...                                 ...
# 259  single-expectation  avg_cv_adjvar_test_full_comparison
# 260  single-expectation                         adj_dropout
# 261    single-cognitive                  avg_cv_adjvar_test
# 262    single-cognitive  avg_cv_adjvar_test_full_comparison
# 263    single-cognitive                         adj_dropout
#
# [264 rows x 4 columns]

# %%
results_summary = pd.pivot_table(results_summary.drop(columns=['dropout_name']), index=['dropout'],columns=['type'],values =['variance_explained'])
results_summary.columns = results_summary.columns.droplevel()
results_summary = results_summary.rename(columns={
    'avg_cv_adjvar_test': 'adj_variance_explained',
    'avg_cv_adjvar_test_full_comparison': 'adj_variance_explained_full',
    'adj_dropout': 'adj_fraction_change_from_full'
})
results_summary
# Out:
# type                adj_fraction_change_from_full  adj_variance_explained  \
# dropout
# Full                                     0.000000                0.094634
# all-images                              -0.013321                0.097219
# behavioral                              -0.668062                0.031427
# change                                  -0.001711                0.127210
# change_and_rewards                      -0.053790                0.175499
# ...                                           ...                     ...
# single-visual                            0.000000                0.000700
# task                                    -0.063397                0.151349
# time                                     0.000000                0.094726
# trial_type                               0.000000                0.000000
# visual                                  -0.009388                0.093746
#
# type                adj_variance_explained_full
# dropout
# Full                                   0.094634
# all-images                             0.098532
# behavioral                             0.094678
# change                                 0.127428
# change_and_rewards                     0.185476
# ...                                         ...
# single-visual                          0.094634
# task                                   0.161594
# time                                   0.094634
# trial_type                             0.000000
# visual                                 0.094634
#
# [88 rows x 3 columns]

# %%
results_summary = gat.generate_results_summary(self.glm)
results_summary
# Out:
#       absolute_change_from_full  variance_explained  variance_explained_full  \
# 0                      0.000000            0.008935                 0.008935
# 1                     -0.000383            0.008552                 0.008935
# 2                     -0.003169            0.005766                 0.008935
# 3                      0.000199            0.009134                 0.008935
# 4                      0.000357            0.009292                 0.008935
# ...                         ...                 ...                      ...
# 3867                  -0.093935            0.000700                 0.094634
# 3868                  -0.006172            0.088462                 0.094634
# 3869                   0.000092            0.094726                 0.094634
# 3870                  -0.000167            0.094467                 0.094634
# 3871                  -0.000888            0.093746                 0.094634
#
#       fraction_change_from_full  cell_specimen_id  \
# 0                      0.000000        1022738347
# 1                     -0.042877        1022738347
# 2                     -0.354685        1022738347
# 3                      0.000000        1022738347
# 4                      0.000000        1022738347
# ...                         ...               ...
# 3867                   0.000000        1022739044
# 3868                  -0.065220        1022739044
# 3869                   0.000000        1022739044
# 3870                  -0.001764        1022739044
# 3871                  -0.009388        1022739044
#
#       adj_fraction_change_from_full  adj_variance_explained  \
# 0                          0.000000                0.008935
# 1                         -0.037372                0.010430
# 2                         -0.353433                0.005776
# 3                          0.000000                0.001981
# 4                          0.000000                0.010251
# ...                             ...                     ...
# 3867                       0.000000                0.000700
# 3868                      -0.063397                0.151349
# 3869                       0.000000                0.094726
# 3870                       0.000000                0.000000
# 3871                      -0.009388                0.093746
#
#       adj_variance_explained_full
# 0                        0.008935
# 1                        0.010835
# 2                        0.008933
# 3                        0.001513
# 4                        0.009048
# ...                           ...
# 3867                     0.094634
# 3868                     0.161594
# 3869                     0.094634
# 3870                     0.000000
# 3871                     0.094634
#
# [3872 rows x 8 columns]

# %%
gat.retrieve_results(search_dict={
    'glm_version':version,
    'cell_specimen_id':cell_specimen_id
},results_type='summary')
# Out:
#                          _id             dropout  absolute_change_from_full  \
# 0   5f6eb70e3252752bf8f8e1d7                Full                   0.000000
# 1   5f6eb70e3252752bf8f8e1d8          all-images                  -0.001194
# 2   5f6eb70e3252752bf8f8e1d9          behavioral                  -0.063200
# 3   5f6eb70e3252752bf8f8e1da              change                  -0.000101
# 4   5f6eb70e3252752bf8f8e1db  change_and_rewards                  -0.005560
# ..                       ...                 ...                        ...
# 83  5f6eb70e3252752bf8f8e22a       single-visual                  -0.093935
# 84  5f6eb70e3252752bf8f8e22b                task                  -0.006172
# 85  5f6eb70e3252752bf8f8e22c                time                   0.000092
# 86  5f6eb70e3252752bf8f8e22d          trial_type                  -0.000167
# 87  5f6eb70e3252752bf8f8e22e              visual                  -0.000888
#
#     variance_explained  variance_explained_full  fraction_change_from_full  \
# 0             0.094634                 0.094634                   0.000000
# 1             0.093441                 0.094634                  -0.012616
# 2             0.031434                 0.094634                  -0.667833
# 3             0.094533                 0.094634                  -0.001070
# 4             0.089074                 0.094634                  -0.058752
# ..                 ...                      ...                        ...
# 83            0.000700                 0.094634                   0.000000
# 84            0.088462                 0.094634                  -0.065220
# 85            0.094726                 0.094634                   0.000000
# 86            0.094467                 0.094634                  -0.001764
# 87            0.093746                 0.094634                  -0.009388
#
#     cell_specimen_id  adj_fraction_change_from_full  adj_variance_explained  \
# 0         1022739044                       0.000000                0.094634
# 1         1022739044                      -0.013321                0.097219
# 2         1022739044                      -0.668062                0.031427
# 3         1022739044                      -0.001711                0.127210
# 4         1022739044                      -0.053790                0.175499
# ..               ...                            ...                     ...
# 83        1022739044                       0.000000                0.000700
# 84        1022739044                      -0.063397                0.151349
# 85        1022739044                       0.000000                0.094726
# 86        1022739044                       0.000000                0.000000
# 87        1022739044                      -0.009388                0.093746
#
#     adj_variance_explained_full  ... published_at  super_container_id  \
# 0                      0.094634  ...          NaN           929817917
# 1                      0.098532  ...          NaN           929817917
# 2                      0.094678  ...          NaN           929817917
# 3                      0.127428  ...          NaN           929817917
# 4                      0.185476  ...          NaN           929817917
# ..                          ...  ...          ...                 ...
# 83                     0.094634  ...          NaN           929817917
# 84                     0.161594  ...          NaN           929817917
# 85                     0.094634  ...          NaN           929817917
# 86                     0.000000  ...          NaN           929817917
# 87                     0.094634  ...          NaN           929817917
#
#              cre_line session_tags  failure_tags  exposure_number  \
# 0   Slc17a7-IRES2-Cre          NaN           NaN                1
# 1   Slc17a7-IRES2-Cre          NaN           NaN                1
# 2   Slc17a7-IRES2-Cre          NaN           NaN                1
# 3   Slc17a7-IRES2-Cre          NaN           NaN                1
# 4   Slc17a7-IRES2-Cre          NaN           NaN                1
# ..                ...          ...           ...              ...
# 83  Slc17a7-IRES2-Cre          NaN           NaN                1
# 84  Slc17a7-IRES2-Cre          NaN           NaN                1
# 85  Slc17a7-IRES2-Cre          NaN           NaN                1
# 86  Slc17a7-IRES2-Cre          NaN           NaN                1
# 87  Slc17a7-IRES2-Cre          NaN           NaN                1
#
#    model_outputs_available           location has_events session_number
# 0                    False  Slc17a7_VISam_182      False              5
# 1                    False  Slc17a7_VISam_182      False              5
# 2                    False  Slc17a7_VISam_182      False              5
# 3                    False  Slc17a7_VISam_182      False              5
# 4                    False  Slc17a7_VISam_182      False              5
# ..                     ...                ...        ...            ...
# 83                   False  Slc17a7_VISam_182      False              5
# 84                   False  Slc17a7_VISam_182      False              5
# 85                   False  Slc17a7_VISam_182      False              5
# 86                   False  Slc17a7_VISam_182      False              5
# 87                   False  Slc17a7_VISam_182      False              5
#
# [88 rows x 42 columns]

# %%
import visual_behavior_glm.GLM_params as glm_params
import os

# %%
glm_version = '7_L2_optimize_by_session'
params = glm_params.load_run_json(glm_version)
os.path.join(params['output_dir'],'figures')
# Out:
# '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_7_L2_optimize_by_session/figures'
