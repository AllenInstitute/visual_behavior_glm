# %%
import visual_behavior_glm.GLM_visualization_tools as gvt
import visual_behavior_glm.GLM_analysis_tools as gat
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# %matplotlib notebook
# %widescreen
# Out:
# <style>.container { width:100% !important; }</style>
# applied a custom magic command to make full use of screen width
# will only work if command is defined locally
# replace with the following to replicate functionality:
# 	from IPython.core.display import display, HTML
# 	display(HTML("<style>.container { width:100% !important; }</style>")

# %%
results = gat.retrieve_results({'glm_version':'9a_L2_optimize_by_session'})

# %%
print(results.columns)
# Out:
# Index(['_id', 'cell_specimen_id', 'Full__avg_cv_var_train',
#        'Full__avg_cv_var_test', 'Full__avg_cv_var_test_full_comparison',
#        'Full__avg_cv_adjvar_train', 'Full__avg_cv_adjvar_test',
#        'Full__avg_cv_adjvar_test_full_comparison',
#        'Full__absolute_change_from_full', 'Full__adj_dropout',
#        ...
#        'published_at', 'super_container_id', 'cre_line', 'session_tags',
#        'failure_tags', 'exposure_number', 'model_outputs_available',
#        'location', 'has_events', 'session_number'],
#       dtype='object', length=772)

# %%
sns.boxplot(
    data=results,
    x='glm_version',
    y='Full__avg_cv_adjvar_test',
    hue='cre_line',
    hue_order=np.sort(results['cre_line'].unique()),
)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import visual_behavior_glm.GLM_visualization_tools as gvt
import visual_behavior_glm.GLM_analysis_tools as gat

results = gat.retrieve_results({'glm_version':'9a_L2_optimize_by_session'})
gvt.compare_var_explained(
    results.rename(columns={
        'Full__avg_cv_var_train':'Full_avg_cv_var_train',
        'Full__avg_cv_var_test':'Full_avg_cv_var_test'
    })
)
# Out:
# <img src="data:image/png;base64,..." width="1498.8889285958853">
# (<Figure size 1500x1200 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3b1976430>,
# ...
#        dtype=object))
