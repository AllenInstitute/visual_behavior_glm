# %%
import visual_behavior_glm.GLM_visualization_tools as gvt
import visual_behavior_glm.GLM_analysis_tools as gat
import seaborn as sns
import numpy as np

# %%
jointplot = gvt.plot_glm_version_comparison(
    comparison_table = None,
    versions_to_compare = ['8a_L2_optimize_by_session','9a_L2_optimize_by_session'],
)

# %%
jointplot = gvt.plot_glm_version_comparison(
    comparison_table = None,
    versions_to_compare = ['8a_L2_optimize_by_session','9b_L2_optimize_by_session'],
)

# %%
jointplot = gvt.plot_glm_version_comparison(
    comparison_table = None,
    versions_to_compare = ['8a_L2_optimize_by_session','9c_L2_optimize_by_session'],
)

# %%
jointplot = gvt.plot_glm_version_comparison(
    comparison_table = None,
    versions_to_compare = ['8a_L2_optimize_by_session','9d_L2_optimize_by_session'],
)
