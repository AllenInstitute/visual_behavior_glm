# %%
import visual_behavior_glm.src.GLM_fit_tools as gft
import matplotlib.pyplot as plt
# Out:
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_api/behavior_ophys_nwb_api.py:9: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# %matplotlib notebook

# %%
# Make run JSON
VERSION = 4
# Load existing parameters
run_params = gft.load_run_json(VERSION)
run_params
# Out:
# {'output_dir': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/',
#  'model_freeze_dir': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/frozen_model_files/',
#  'experiment_output_dir': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/experiment_model_files/',
#  'job_dir': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/log_files/',
#  'manifest': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/manifest/manifest.json',
#  'json_path': '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_4/run_params.json',
#  'beh_model_dir': '/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/',
#  'version': '4',
#  'creation_time': '2020-07-24 14:58:46.614820',
#  'user': 'dougo',
#  'label': 'updated model',
# ...

# %%
# To start all experiments on hpc:
# cd visual_behavior_glm/scripts/
# python start_glm.py VERSION

# To run just one session:
oeid = 808621958
session, fit, design = gft.fit_experiment(oeid, run_params)
# Out:
# Fitting ophys_experiment_id: 808621958
# Loading data
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# Processing df/f data
# Build Design Matrix
#     Adding kernel: intercept
#     Adding kernel: time
#     Adding kernel: pre_licks
#     Adding kernel: post_licks
#     Adding kernel: pre_lick_bouts
#     Adding kernel: post_lick_bouts
#     Adding kernel: rewards
#     Adding kernel: change
#     Adding kernel: hits
#     Adding kernel: misses
#     Adding kernel: false_alarms
#     Adding kernel: correct_rejects
#     Adding kernel: omissions
#     Adding kernel: image_expectation
#     Adding kernel: running
# ...

# %%
# %debug
# Out:
# > /home/dougo/Code/visual_behavior_glm/notebooks/pandas/_libs/hashtable_class_helper.pxi(1627)pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ipdb> q

# %%
os.listdir(run_params['experiment_output_dir'])
# Out:
# ['808621958.pkl', '839716147.pkl']

# %%
output_data = pd.read_pickle(os.path.join(run_params['experiment_output_dir'],'{}.pkl'.format(oeid)))

# %%
output_data.keys()
# Out:
# dict_keys(['dff_trace_arr', 'dff_trace_timestamps', 'dff_trace_bins', 'splits', 'dropouts'])

# %%
output_data['dff_trace_arr'].values.shape
# Out:
# (111667, 45)

# %%
len(output_data['dff_trace_timestamps'])
# Out:
# 111667

# %%
output_data['dff_trace_bins'].shape[0]
# Out:
# 111668

# %%
output_data['splits']
# Out:
# [array([82638, 82639, 82640, ..., 51373, 51374, 51375]),
#  array([ 6702,  6703,  6704, ..., 89334, 89335, 89336]),
#  array([37978, 37979, 37980, ..., 37975, 37976, 37977]),
#  array([46910, 46911, 46912, ..., 24571, 24572, 24573]),
#  array([89337, 89338, 89339, ..., 20103, 20104, 20105])]

# %%
for i in range(len(output_data['splits'])):
    print('shape of splits[{}]: {}'.format(i,output_data['splits'][i].shape))
# Out:
# shape of splits[0]: (22334,)
# shape of splits[1]: (22333,)
# shape of splits[2]: (22332,)
# shape of splits[3]: (22334,)
# shape of splits[4]: (22334,)

# %%
output_data['dropouts'].keys()
# Out:
# dict_keys(['Full', 'licks', 'rewards', 'change'])

# %%
output_data['dropouts']['Full'].keys()
# Out:
# dict_keys(['kernels', 'variance_explained', 'cv_var_train', 'cv_var_test'])

# %%
output_data['dropouts']['Full']['kernels']
# Out:
# ['licks', 'rewards', 'change']

# %%
output_data['dropouts']['Full']['variance_explained'].values.max()
# Out:
# 0.006460534641136073

# %%
output_data['dropouts']['Full']['cv_var_train'].shape
# Out:
# (45, 5)

# %%
output_data['dropouts']['Full']['cv_var_test'].shape
# Out:
# (45, 5)

# %%
cell_specimen_id=817102140
